# %%
from ipywidgets import interact

def greet(name):
    print ( f'Hello, {name}!')

interact(greet, name='Greet')
# Out:
# interactive(children=(Text(value='Greet', description='name'), Output()), _dom_classes=('widget-interact',))
# <function __main__.greet(name)>
