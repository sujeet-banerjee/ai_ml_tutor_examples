# %%
def fibb (n=100):

    if n == 1:
        return 1
    elif n == 0:
        return 1

    print('working on n=', n)
    newValue = fibb(n-1) + fibb(n-2)

    return newValue

# Call it
ans = fibb(15)
print("ans = ", ans)
# Out:
# working on n= 15
# working on n= 14
# working on n= 13
# working on n= 12
# working on n= 11
# working on n= 10
# working on n= 9
# working on n= 8
# working on n= 7
# working on n= 6
# working on n= 5
# working on n= 4
# working on n= 3
# working on n= 2
# working on n= 2
# working on n= 3
# working on n= 2
# working on n= 4
# working on n= 3
# working on n= 2
# working on n= 2
# working on n= 5
# working on n= 4
# working on n= 3
# working on n= 2
# working on n= 2
# working on n= 3
# working on n= 2
# working on n= 6
# working on n= 5
# working on n= 4
# working on n= 3
# working on n= 2
# working on n= 2
# working on n= 3
# working on n= 2
# working on n= 4
# working on n= 3
# working on n= 2
# working on n= 2
# working on n= 7
# working on n= 6
# working on n= 5
# working on n= 4
# working on n= 3
# working on n= 2
# working on n= 2
# working on n= 3
# working on n= 2
# working on n= 4
# working on n= 3
# working on n= 2
# working on n= 2
# working on n= 5
# working on n= 4
# ...
